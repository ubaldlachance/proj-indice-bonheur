# %% [markdown]
# Ce notebook sert à faire la composition du jeu de données des différences depuis l'année précédente à partir du jeu de données des indices de bonheur et indicateurs.
# Fichier de données requis: data/merged/global_cluster.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.cluster import KMeans
from math import log, sqrt

# %%
df_global = pd.read_csv("data/merged/global_cluster.csv", sep=";")

# %%
df_global.head()
# Out:
#    annee      Country  Happiness Score  nativity  migration  health_expend  \
# 0   2015  Switzerland            7.587     10.50       4.74           11.5
# 1   2015      Iceland            7.561     13.91       4.43            9.1
# 2   2015      Denmark            7.527     10.27       2.20           10.6
# 3   2015       Norway            7.522     12.14       7.25            9.6
# 4   2015       Canada            7.427     10.28       5.66           10.9
#
#    educ_expend      gdp  taxes  budget  milit  cluster_init  cluster
# 0          5.3  58100.0   33.6     0.3   0.64             0        1
# 1          7.4  43600.0   45.3     0.1   0.13             0        0
# 2          8.7  44300.0   55.5    -1.4   1.37             0        0
# 3          6.6  66900.0   57.5    12.5   1.40             1        1
# 4          5.3  44800.0   37.6    -2.3   1.00             0        0

# %%
df_global.shape[0]
# Out:
# 1338

# %%
df_global.groupby("Country").count()
# Out:
#              annee  Happiness Score  nativity  migration  health_expend  \
# Country
# Afghanistan      9                9         9          9              9
# Albania          9                9         9          9              9
# Algeria          9                9         9          9              9
# Angola           4                4         4          4              4
# Argentina        9                9         9          9              9
# ...            ...              ...       ...        ...            ...
# Venezuela        9                9         9          9              9
# Vietnam          9                9         9          9              9
# Yemen            8                8         8          8              8
# Zambia           9                9         9          9              9
# Zimbabwe         9                9         9          9              9
#
#              educ_expend  gdp  taxes  budget  milit  cluster_init  cluster
# Country
# Afghanistan            9    9      9       9      9             9        9
# Albania                9    9      9       9      9             9        9
# Algeria                9    9      9       9      9             9        9
# Angola                 4    4      4       4      4             4        4
# Argentina              9    9      9       9      9             9        9
# ...                  ...  ...    ...     ...    ...           ...      ...
# Venezuela              9    9      9       9      9             9        9
# Vietnam                9    9      9       9      9             9        9
# Yemen                  8    8      8       8      8             8        8
# Zambia                 9    9      9       9      9             9        9
# Zimbabwe               9    9      9       9      9             9        9
#
# [160 rows x 12 columns]

# %%
df_global[df_global.Country=="Angola"]
# Out:
#      annee Country  Happiness Score  nativity  migration  health_expend  \
# 132   2015  Angola            4.033     38.78       0.46            3.8
# 289   2016  Angola            3.866     38.60      -0.10            3.3
# 442   2017  Angola            3.795     44.20       0.20            3.3
# 596   2018  Angola            3.795     43.70       0.20            3.3
#
#      educ_expend     gdp  taxes  budget  milit  cluster_init  cluster
# 132          3.5  7200.0   39.2    -4.7   3.63             2        2
# 289          3.4  7300.0   32.2    -5.2   3.63             2        2
# 442          3.5  6800.0   29.9    -6.2   2.95             2        2
# 596          3.5  6800.0   29.3    -6.7   2.95             2        2

# %%
df_global[["Country"]].value_counts().loc[lambda cpt: cpt>1].reset_index(name="compte").Country
# Out:
# 0      Afghanistan
# 1        Nicaragua
# 2       Montenegro
# 3          Morocco
# 4          Myanmar
#           ...
# 153        Somalia
# 154          Sudan
# 155         Belize
# 156       Suriname
# 157       Maldives
# Name: Country, Length: 158, dtype: object

# %%
df_global[df_global.Country=="Afghanistan"].sort_values(by="annee", ascending=False)
# Out:
#       annee      Country  Happiness Score  nativity  migration  health_expend  \
# 1337   2023  Afghanistan           1.8590     34.79      -0.10           15.5
# 1202   2022  Afghanistan           2.4040     35.46      -0.10           13.2
# 1059   2021  Afghanistan           2.5230     36.08      -0.10            9.4
# 913    2020  Afghanistan           2.5669     36.70      -0.10           11.8
# 761    2019  Afghanistan           3.2030     37.50      -0.60           10.2
# 599    2018  Afghanistan           3.6320     37.50      -0.90            8.2
# 443    2017  Afghanistan           3.7940     37.90      -0.90            8.2
# 302    2016  Afghanistan           3.3600     38.30      -1.20            8.2
# 148    2015  Afghanistan           3.5750     38.57      -1.51            8.1
#
#       educ_expend     gdp  taxes  budget  milit  cluster_init  cluster
# 1337          2.9  1500.0    9.9   -15.1   3.10             2        2
# 1202          2.9  2000.0   11.2   -15.1   3.30             2        2
# 1059          3.2  2000.0   11.2   -15.1   1.20             2        2
# 913           4.1  2000.0   11.2   -15.1   1.20             2        2
# 761           4.1  2000.0   11.2   -15.1   0.99             2        2
# 599           3.2  2000.0   11.2   -15.1   0.89             2        2
# 443           3.4  2000.0   10.5   -24.6   0.89             2        2
# 302           3.4  1900.0    8.2   -23.7  28.09             2        2
# 148           3.4  1900.0   22.6    -0.6  28.09             2        2

# %%
def creer_df_diffs(df_in: pd.DataFrame) -> pd.DataFrame:
    lst_out = []
    df_in = df_in.rename(columns={"Happiness Score": "Indice_bonheur"})
    
    # Boucle sur tout les pays qui apparaissent plus d'une année. 
    for pays in df_in[["Country"]].value_counts().loc[lambda cpt: cpt>1].reset_index(name="compte").Country:
        enreg_suivant = None
        
        # Bouble sur les années du pays, descendente
        for enreg_courrant in df_in[df_in.Country == pays].sort_values(by="annee", ascending=False).itertuples():
            if enreg_suivant:
                lst_out.append({
                    "Annee": enreg_suivant.annee,
                    "Pays": pays,
                    "Indice_bonheur": enreg_suivant.Indice_bonheur - enreg_courrant.Indice_bonheur,
                    "Natalité": enreg_suivant.nativity - enreg_courrant.nativity,
                    "Migration": enreg_suivant.migration - enreg_courrant.migration,
                    "Dépenses_santé": enreg_suivant.health_expend - enreg_courrant.health_expend,
                    "Dépenses_éduc": enreg_suivant.educ_expend - enreg_courrant.educ_expend,
                    "PIB": enreg_suivant.gdp - enreg_courrant.gdp,
                    "Taxes_rev": enreg_suivant.taxes - enreg_courrant.taxes,
                    "Budget_equil": enreg_suivant.budget - enreg_courrant.budget,
                    "Dépenses_milit": enreg_suivant.milit - enreg_courrant.milit,
                    "Regroupement": enreg_suivant.cluster
                })
            
            enreg_suivant = enreg_courrant
            
    return pd.DataFrame(lst_out)

# %%
df_diffs = creer_df_diffs(df_global)

# %% [markdown]
# ### On peut voir un exemple de résultat, pour la France

# %%
df_global[df_global.Country=="France"].sort_values(by="annee", ascending=False)
# Out:
#       annee Country  Happiness Score  nativity  migration  health_expend  \
# 1223   2023  France           6.6610     11.56       1.06           12.2
# 1079   2022  France           6.6870     11.66       1.06           11.1
# 934    2021  France           6.6900     11.77       1.06           11.3
# 786    2020  France           6.6638     11.90       1.10           11.3
# 634    2019  France           6.5920     12.10       1.10           11.5
# 480    2018  France           6.4890     12.10       1.10           11.5
# 336    2017  France           6.4420     12.20       1.10           11.5
# 184    2016  France           6.4780     12.30       1.10           11.5
# 28     2015  France           6.5750     12.38       1.09           11.7
#
#       educ_expend      gdp  taxes  budget  milit  cluster_init  cluster
# 1223          5.5  45000.0  24.69    -2.6   1.79             0        0
# 1079          5.5  42000.0  53.80    -2.6   1.90             0        0
# 934           5.4  42000.0  53.80    -2.6   2.04             0        0
# 786           5.5  45739.0  53.80    -2.6   1.84             0        0
# 634           5.4  44100.0  53.80    -2.6   1.84             0        0
# 480           5.5  44100.0  53.80    -2.6   1.79             0        0
# 336           5.5  42300.0  53.10    -3.4   2.26             0        0
# 184           5.5  41200.0  53.40    -3.6   1.80             0        0
# 28            5.9  40400.0  51.90    -4.3   1.80             0        0

# %%
df_diffs[df_diffs.Pays=="France"]
# Out:
#      Annee    Pays  Indice_bonheur  Natalité  Migration  Dépenses_santé  \
# 968   2023  France         -0.0260     -0.10       0.00             1.1
# 969   2022  France         -0.0030     -0.11       0.00            -0.2
# 970   2021  France          0.0262     -0.13      -0.04             0.0
# 971   2020  France          0.0718     -0.20       0.00            -0.2
# 972   2019  France          0.1030      0.00       0.00             0.0
# 973   2018  France          0.0470     -0.10       0.00             0.0
# 974   2017  France         -0.0360     -0.10       0.00             0.0
# 975   2016  France         -0.0970     -0.08       0.01            -0.2
#
#      Dépenses_éduc     PIB  Taxes_rev  Budget_equil  Dépenses_milit  \
# 968            0.0  3000.0     -29.11           0.0           -0.11
# 969            0.1     0.0       0.00           0.0           -0.14
# 970           -0.1 -3739.0       0.00           0.0            0.20
# 971            0.1  1639.0       0.00           0.0            0.00
# 972           -0.1     0.0       0.00           0.0            0.05
# 973            0.0  1800.0       0.70           0.8           -0.47
# 974            0.0  1100.0      -0.30           0.2            0.46
# 975           -0.4   800.0       1.50           0.7            0.00
#
#      Regroupement
# 968             0
# 969             0
# 970             0
# 971             0
# 972             0
# 973             0
# 974             0
# 975             0

# %% [markdown]
# ## Évaluations des corrélations entre les différences des variables et celles de l'indice de bonheur

# %% [markdown]
# ### Natalité

# %%
plt.scatter(df_diffs.Natalité, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('Natalité /1000 pop')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Natalité.notnull()]
c_nat = stats.pearsonr(df_temp.Natalité, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 6.855372817106008e-06

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Natalité, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Natalité, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Natalité, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('Natalité /1000 pop')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Natalité.notnull())]
    c_nat = stats.pearsonr(df_temp.Natalité, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.00036937064373813983
# r2 cluster 1: 0.06746571923460427
# r2 cluster 2: 7.383671891679533e-06

# %% [markdown]
# ### Migration

# %%
plt.scatter(df_diffs.Migration, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('migrants /1000 pop')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Migration.notnull()]
c_nat = stats.pearsonr(df_temp.Migration, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 0.0007455768770639895

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Migration, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Migration, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Migration, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('migrants /1000 pop')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Migration.notnull())]
    c_nat = stats.pearsonr(df_temp.Migration, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.01500637299630916
# r2 cluster 1: 0.044264247350666364
# r2 cluster 2: 0.0011010296389778488

# %% [markdown]
# ### Dépenses en santé

# %%
plt.scatter(df_diffs.Dépenses_santé, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('dépense de santé, % PIB')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Dépenses_santé.notnull()]
c_nat = stats.pearsonr(df_temp.Dépenses_santé, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 0.0034733981518716545

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Dépenses_santé, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Dépenses_santé, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Dépenses_santé, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('dépense de santé, % PIB')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Dépenses_santé.notnull())]
    c_nat = stats.pearsonr(df_temp.Dépenses_santé, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.015327828173212755
# r2 cluster 1: 0.013283791551941579
# r2 cluster 2: 0.002799378343354743

# %% [markdown]
# ### Dépenses en éducation

# %%
plt.scatter(df_diffs.Dépenses_éduc, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('dépense en éducation, % PIB')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Dépenses_éduc.notnull()]
c_nat = stats.pearsonr(df_temp.Dépenses_éduc, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 0.001248302013863097

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Dépenses_éduc, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Dépenses_éduc, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Dépenses_éduc, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('dépense en éducation, % PIB')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Dépenses_éduc.notnull())]
    c_nat = stats.pearsonr(df_temp.Dépenses_éduc, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.0023730504837384428
# r2 cluster 1: 0.001981767119784316
# r2 cluster 2: 0.0023361702841162104

# %% [markdown]
# ### PIB per capitat

# %%
plt.scatter(df_diffs.PIB, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('PIB per capitat')
plt.show()

# %%
df_temp = df_diffs[df_diffs.PIB.notnull()]
c_nat = stats.pearsonr(df_temp.PIB, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 5.21610709772897e-06

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].PIB, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].PIB, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].PIB, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('PIB per capitat')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.PIB.notnull())]
    c_nat = stats.pearsonr(df_temp.PIB, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.00035925164543981584
# r2 cluster 1: 0.0017798813864673946
# r2 cluster 2: 1.465292742358231e-05

# %% [markdown]
# ### Taxes et autres revenus

# %%
plt.scatter(df_diffs.Taxes_rev, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('Taxes et autres revenus % PIB')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Taxes_rev.notnull()]
c_nat = stats.pearsonr(df_temp.Taxes_rev, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 0.0052906009922878035

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Taxes_rev, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Taxes_rev, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Taxes_rev, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('Taxes et autres revenus % PIB')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Taxes_rev.notnull())]
    c_nat = stats.pearsonr(df_temp.Taxes_rev, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.00798376123325921
# r2 cluster 1: 0.10487675330483434
# r2 cluster 2: 0.005751379337525232

# %% [markdown]
# ### Surplus ou déficit budgétaire

# %%
plt.scatter(df_diffs.Budget_equil, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('Surplus ou déficit budgétaire % PIB')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Budget_equil.notnull()]
c_nat = stats.pearsonr(df_temp.Budget_equil, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 7.852402404139189e-05

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Budget_equil, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Budget_equil, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Budget_equil, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('Surplus ou déficit budgétaire % PIB')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Budget_equil.notnull())]
    c_nat = stats.pearsonr(df_temp.Budget_equil, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.0013878996553909682
# r2 cluster 1: 0.045265244887914835
# r2 cluster 2: 4.2824522924086064e-07

# %% [markdown]
# ### Dépenses militaires

# %%
plt.scatter(df_diffs.Dépenses_milit, df_diffs["Indice_bonheur"], s=10)
plt.ylabel('Indice bonheur')
plt.xlabel('Dépense militaire % PIB')
plt.show()

# %%
df_temp = df_diffs[df_diffs.Dépenses_milit.notnull()]
c_nat = stats.pearsonr(df_temp.Dépenses_milit, df_temp["Indice_bonheur"])
c_nat.statistic**2
# Out:
# 0.0010990539834897582

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True, sharex=True)
axs[0].scatter(df_diffs[df_diffs.Regroupement==0].Dépenses_milit, df_diffs[df_diffs.Regroupement==0]["Indice_bonheur"], s=10)
axs[1].scatter(df_diffs[df_diffs.Regroupement==1].Dépenses_milit, df_diffs[df_diffs.Regroupement==1]["Indice_bonheur"], s=10)
axs[2].scatter(df_diffs[df_diffs.Regroupement==2].Dépenses_milit, df_diffs[df_diffs.Regroupement==2]["Indice_bonheur"], s=10)

axs[0].set_ylabel('Indice bonheur')
for ax in axs:
    ax.set_xlabel('Dépense militaire % PIB')
for i in range(0, len(axs)):
    axs[i].set_title(f'Regroupement {i}')

# %%
for i in range(0,3):
    df_temp = df_diffs[(df_diffs.Regroupement==i) & (df_diffs.Dépenses_milit.notnull())]
    c_nat = stats.pearsonr(df_temp.Dépenses_milit, df_temp["Indice_bonheur"])
    print(f"r2 cluster {i}: {c_nat.statistic**2}")
# Out:
# r2 cluster 0: 0.004481877433754588
# r2 cluster 1: 0.022526272900758294
# r2 cluster 2: 0.001815089663205101

# %% [markdown]
# ## Nouveau clustering (regroupement)

# %% [markdown]
# Ici nous allons faire un nouveau regroupement basé directement sur le jeu de données des différences.

# %%
df_diffs.head()
# Out:
#    Annee         Pays  Indice_bonheur  Natalité  Migration  Dépenses_santé  \
# 0   2023  Afghanistan         -0.5450     -0.67        0.0             2.3
# 1   2022  Afghanistan         -0.1190     -0.62        0.0             3.8
# 2   2021  Afghanistan         -0.0439     -0.62        0.0            -2.4
# 3   2020  Afghanistan         -0.6361     -0.80        0.5             1.6
# 4   2019  Afghanistan         -0.4290      0.00        0.3             2.0
#
#    Dépenses_éduc    PIB  Taxes_rev  Budget_equil  Dépenses_milit  Regroupement
# 0            0.0 -500.0       -1.3           0.0           -0.20             2
# 1           -0.3    0.0        0.0           0.0            2.10             2
# 2           -0.9    0.0        0.0           0.0            0.00             2
# 3            0.0    0.0        0.0           0.0            0.21             2
# 4            0.9    0.0        0.0           0.0            0.10             2

# %%
df_naif = df_diffs.drop(columns=["Annee","Pays"])

# %%
# Segmentation en 4 regroupements.
kmeans = KMeans(n_clusters=4, random_state=84, n_init=3).fit(df_naif)

# %%
print("Nombre d'observations par cluster")
print(f"cluster 0: {df_diffs.loc[kmeans.labels_ ==0].shape[0]}")
print(f"cluster 1: {df_diffs.loc[kmeans.labels_ ==1].shape[0]}")
print(f"cluster 2: {df_diffs.loc[kmeans.labels_ ==2].shape[0]}")
print(f"cluster 3: {df_diffs.loc[kmeans.labels_ ==3].shape[0]}")
# Out:
# Nombre d'observations par cluster
# cluster 0: 1046
# cluster 1: 68
# cluster 2: 59
# cluster 3: 5

# %%
df_diffs.loc[kmeans.labels_ ==1]
# Out:
#       Annee                 Pays  Indice_bonheur  Natalité  Migration  \
# 27     2020              Morocco         -0.1132      0.40       1.20
# 115    2020               Panama         -0.0162     -0.50       0.10
# 139    2020               Mexico         -0.1300     -0.50      -0.10
# 147    2020          Philippines          0.3750     -0.50       0.10
# 155    2020            Lithuania          0.0665     -0.30       0.20
# ...     ...                  ...             ...       ...        ...
# 1132   2020  Trinidad and Tobago         -0.0001     -0.90       0.40
# 1151   2020             Eswatini          0.0961     -1.30       0.10
# 1159   2017                Qatar          0.0000     -0.10      -3.60
# 1160   2016                Qatar         -0.2360     -0.14      -4.19
# 1177   2021             Maldives          0.0004     -0.31      -0.06
#
#       Dépenses_santé  Dépenses_éduc      PIB  Taxes_rev  Budget_equil  \
# 27              -0.6       0.000000  -5150.0        0.0           0.0
# 115              0.0       0.000000 -13490.0        0.0           0.0
# 139              0.0      -0.400000  -9625.0        0.0           0.0
# 147              0.0       0.000000  -5060.0        0.0           0.0
# 155             -0.2      -0.400000 -13556.0        0.0           0.0
# ...              ...            ...      ...        ...           ...
# 1132             0.5      -0.175264 -16115.0        0.0           0.0
# 1151            -0.8       0.000000  -5279.0        0.0           0.0
# 1159             0.0       0.000000  -7000.0       -5.7          -8.8
# 1160             0.0       1.100000 -11300.0      -12.0         -10.7
# 1177             0.4       0.000000  -6200.0        0.0           0.0
#
#       Dépenses_milit  Regroupement
# 27          0.000000             2
# 115         0.000000             0
# 139        -0.040000             2
# 147        -0.130000             2
# 155         0.000000             0
# ...              ...           ...
# 1132       -0.080000             0
# 1151        0.300000             2
# 1159       -0.140017             1
# 1160        0.262003             1
# 1177        0.074840             2
#
# [68 rows x 12 columns]

# %%
df_diffs.loc[kmeans.labels_ ==2]
# Out:
#       Annee                    Pays  Indice_bonheur  Natalité  Migration  \
# 74     2021                 Moldova          0.1585     -0.25       0.05
# 99     2020                  Norway         -0.0660      0.00      -1.30
# 114    2021                  Panama         -0.1248     -0.43      -0.01
# 138    2021                  Mexico         -0.1480     -0.31       0.44
# 154    2021               Lithuania          0.0395     -0.08       1.15
# 162    2021                  Kosovo          0.0468     -0.35       0.36
# 178    2021                  Latvia          0.0820     -0.24       0.58
# 194    2021                 Albania          0.2343     -0.14       0.06
# 211    2020              Luxembourg          0.1475      0.00      -1.50
# 214    2017              Luxembourg         -0.0080      0.10      -0.80
# 215    2016              Luxembourg         -0.0750      0.03      -0.86
# 242    2021                Malaysia         -0.0003     -3.58       1.79
# 282    2021                  Poland         -0.0203     -0.21      -0.03
# 290    2021              Kazakhstan          0.0941     -0.53      -0.01
# 306    2021                Thailand         -0.0138     -0.45      -0.03
# 330    2021                 Turkiye         -0.1838     -0.26       2.75
# 402    2021                 Vietnam          0.0575      1.54       0.07
# 424    2023                  Taiwan          0.0230     -0.06       0.11
# 434    2021                Portugal          0.0181     -0.08       0.32
# 440    2023               Singapore          0.1070     -0.11      -0.04
# 442    2021               Singapore         -0.0001      0.23      -7.54
# 445    2018               Singapore         -0.2290      0.10       0.00
# 450    2021                 Romania          0.0163     -0.11       0.00
# 458    2021                  Russia         -0.0690     -0.29       0.00
# 482    2021                  Serbia          0.2998     -0.06       0.00
# 498    2021                Slovakia          0.0504     -0.20       0.00
# 507    2020             Switzerland          0.0799      0.00       0.00
# 514    2021                Slovenia          0.0976     -0.20       0.04
# 530    2021             South Korea         -0.0274     -1.31       0.35
# 546    2021               Sri Lanka         -0.0020     -0.19       0.06
# 555    2020                  Sweden          0.0105      0.00      -0.10
# 578    2021                  Jordan         -0.2384     -0.21       0.13
# 611    2020                 Denmark          0.0456      0.20      -1.50
# 618    2021                 Czechia          0.0541     -0.15       0.02
# 626    2021                  Cyprus          0.0640     -0.14      -0.31
# 634    2021                 Croatia          0.3773     -0.02       0.26
# 643    2020                   Japan         -0.0152     -0.20       0.00
# 666    2021                   China          0.2151     -0.30      -0.03
# 674    2021                   Chile         -0.0565     -0.18       0.03
# 722    2021                Bulgaria          0.1645     -0.15       0.01
# 746    2021  Bosnia and Herzegovina          0.1389     -0.10       0.02
# 784    2023                 Bahrain         -0.4740     -0.10      -0.17
# 786    2021                 Bahrain          0.4197     -0.20     -11.27
# 803    2020               Australia         -0.0052      0.40       2.70
# 807    2016               Australia          0.0290     -0.05      -0.05
# 818    2021               Argentina         -0.0457     -0.20       0.02
# 834    2021                   Egypt          0.1316     -0.76      -0.04
# 850    2021                 Estonia          0.1672     -0.27       0.25
# 874    2021                 Hungary         -0.0084     -0.08      -0.06
# 904    2023                 Ireland         -0.1300     -0.24      -0.03
# 906    2021                 Ireland         -0.0087     -0.40      -0.07
# 907    2020                 Ireland          0.0727     -0.80      -0.10
# 910    2017                 Ireland          0.0700     -0.40       0.00
# 911    2016                 Ireland         -0.0330     -0.34      -0.09
# 1018   2021               Indonesia          0.0594      0.19       0.38
# 1047   2021              Azerbaijan          0.0062     -0.47       0.00
# 1054   2021                 Belarus         -0.0059     -0.18       0.02
# 1061   2021            Turkmenistan         -0.0531     -0.45      -0.02
# 1082   2021                  Kuwait          0.0039     -0.10      -0.35
#
#       Dépenses_santé  Dépenses_éduc      PIB  Taxes_rev  Budget_equil  \
# 74         -0.400000       0.700000   9859.0       0.00           0.0
# 99         -0.100000      -0.100000  19681.0       0.00           0.0
# 114         0.000000      -0.100000  13490.0       0.00           0.0
# 138        -0.100000      -0.200000   7625.0       0.00           0.0
# 154         0.100000       0.100000  17856.0       0.00           0.0
# 162        -0.063208       0.044253   6519.0       0.00           0.0
# 178         0.200000      -0.200000  13122.0       0.00           0.0
# 194        -1.400000       0.300000   8144.0       0.00           0.0
# 211        -0.700000      -0.300000   6909.0       0.00           0.0
# 214         0.000000       0.000000   6800.0       0.00           0.3
# 215        -0.500000       0.000000   7000.0      -0.60           1.1
# 242        -0.100000       0.000000  13918.0       0.00           0.0
# 282        -0.200000       0.000000  13432.0       0.00           0.0
# 290        -0.200000       0.300000  13455.0       0.00           0.0
# 306         0.100000      -1.100000  10677.0       0.00           0.0
# 330        -0.100000       0.000000  13325.0       0.00           0.0
# 402         0.400000      -0.100000   6075.0       0.00           0.0
# 424         0.546203      -0.045656  20898.0       0.00           0.0
# 434         0.400000      -0.300000   7392.0       0.00           0.0
# 440         2.000000       0.000000  12600.0      -2.81           0.0
# 442         0.100000      -0.400000  35547.0       0.00           0.0
# 445         0.000000       0.000000   6300.0      -0.90           0.9
# 450         0.400000       0.200000  16789.0       0.00           0.0
# 458         0.000000       0.000000  13658.0       0.00           0.0
# 482         0.100000       0.000000  10932.0       0.00           0.0
# 498         0.000000       0.100000   9234.0       0.00           0.0
# 507         0.100000       0.000000  19375.0       0.00           0.0
# 514         0.100000       0.100000   8869.0       0.00           0.0
# 530         0.000000       0.200000  13359.0       0.00           0.0
# 546         0.000000       0.000000   8397.0       0.00           0.0
# 555         0.100000      -0.100000   8499.0       0.00           0.0
# 578        -0.300000      -0.100000   6509.0       0.00           0.0
# 611        -0.300000       0.200000  16251.0       0.00           0.0
# 618         0.500000       0.400000  12484.0       0.00           0.0
# 626         0.100000       0.000000  13752.0       0.00           0.0
# 634         0.000000       0.000000   9577.0       0.00           0.0
# 643         0.000000      -0.300000   6079.0       0.00           0.0
# 666         0.200000       0.000000   8359.0       0.00           0.0
# 674         0.100000       0.000000   8202.0       0.00           0.0
# 722        -0.700000       0.000000  12512.0       0.00           0.0
# 746         0.000000       0.044253   7659.0       0.00           0.0
# 784         0.200000       0.000000   8500.0       0.00           0.0
# 786        -0.600000       0.000000  17459.0       0.00           0.0
# 803        -0.100000      -0.200000  12353.0       0.00           0.0
# 807         0.000000       0.200000  19000.0       0.70           0.2
# 818         0.500000      -0.700000   9893.0       0.00           0.0
# 834        -0.300000       0.100000   9057.0       0.00           0.0
# 850         0.300000       0.200000  14703.0       0.00           0.0
# 874        -0.200000      -0.100000  13251.0       0.00           0.0
# 904         0.400000       0.000000  12800.0      -9.49           0.0
# 906        -0.300000      -0.100000   8360.0       0.00           0.0
# 907        -0.200000      -0.200000   8140.0       0.00           0.0
# 910         0.000000      -0.500000  13800.0      -5.40           1.8
# 911        -1.100000      -0.400000   6300.0       0.10           2.2
# 1018       -0.100000      -0.800000   6945.0       0.00           0.0
# 1047       -3.200000       0.200000   7837.0       0.00           0.0
# 1054       -0.300000       0.200000  12405.0       0.00           0.0
# 1061       -0.300000       0.000000   7856.0       0.00           0.0
# 1082       -0.300000       2.800000  16813.0       0.00           0.0
#
#       Dépenses_milit  Regroupement
# 74              0.00             2
# 99              0.00             1
# 114             0.00             0
# 138             0.20             2
# 154             0.00             0
# 162             1.20             2
# 178             0.26             0
# 194             0.00             2
# 211             0.00             1
# 214             0.05             1
# 215            -0.16             1
# 242             0.00             0
# 282             0.20             0
# 290             0.00             0
# 306             0.10             2
# 330            -0.03             0
# 402             0.10             2
# 424            -0.40             0
# 434             0.07             0
# 440             0.00             1
# 442             0.00             1
# 445            -0.23             1
# 450            -0.04             0
# 458             0.10             0
# 482            -0.20             2
# 498            -0.01             0
# 507             0.02             1
# 514             0.06             0
# 530            -0.06             0
# 546             0.10             2
# 555             0.06             0
# 578             0.00             2
# 611             0.00             0
# 618             0.15             0
# 626             0.15             0
# 634             1.11             0
# 643             0.00             0
# 666            -0.20             2
# 674             0.20             2
# 722            -1.65             2
# 746             0.00             2
# 784             1.00             0
# 786             0.50             0
# 803             0.01             0
# 807             0.00             0
# 818             0.10             2
# 834             0.00             2
# 850             0.16             0
# 874             0.64             0
# 904             0.00             1
# 906            -0.03             1
# 907            -0.03             1
# 910            -0.15             1
# 911             0.00             1
# 1018            0.10             2
# 1047            1.40             2
# 1054            0.00             2
# 1061            0.00             2
# 1082            0.70             1

# %%
df_diffs.loc[kmeans.labels_ ==3]
# Out:
#       Annee       Pays  Indice_bonheur  Natalité  Migration  Dépenses_santé  \
# 98     2021     Norway         -0.0960     -0.11      -0.05       -0.300000
# 427    2020     Taiwan          0.0094     -0.20      -0.10        0.006522
# 443    2020  Singapore          0.1151      0.20      -0.90        0.100000
# 787    2020    Bahrain          0.0283     -0.40      -1.00       -0.200000
# 1083   2020     Kuwait          0.0811     -0.80      -0.50        1.400000
#
#       Dépenses_éduc      PIB  Taxes_rev  Budget_equil  Dépenses_milit  \
# 98        -0.300000 -28181.0        0.0           0.0            0.20
# 427       -0.175264 -25998.0        0.0           0.0           -0.08
# 443        0.000000 -36247.0        0.0           0.0           -0.10
# 787        0.000000 -25559.0        0.0           0.0            0.10
# 1083       0.000000 -32713.0        0.0           0.0            0.54
#
#       Regroupement
# 98               1
# 427              0
# 443              1
# 787              0
# 1083             1

# %% [markdown]
# La segmentation ne semble pas nous avoir fourni un patern interessant. Peut-être aurons nous plus de chance avec les différences sur la première et dernière année dans le notebook 05B.
